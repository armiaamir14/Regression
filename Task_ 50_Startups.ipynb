# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("50_Startups.csv")
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# 12   93863.75       127320.38        249839.44     Florida  141585.52
# 13   91992.39       135495.07        252664.93  California  134307.35
# 14  119943.24       156547.42        256512.92     Florida  132602.65
# 15  114523.61       122616.84        261776.23    New York  129917.04
# 16   78013.11       121597.55        264346.06  California  126992.93
# 17   94657.16       145077.58        282574.31    New York  125370.37
# 18   91749.16       114175.79        294919.57     Florida  124266.90
# 19   86419.70       153514.11             0.00    New York  122776.86
# 20   76253.86       113867.30        298664.47  California  118474.03
# 21   78389.47       153773.43        299737.29    New York  111313.02
# 22   73994.56       122782.75        303319.26     Florida  110352.25
# 23   67532.53       105751.03        304768.73     Florida  108733.99
# 24   77044.01        99281.34        140574.81    New York  108552.04
# 25   64664.71       139553.16        137962.62  California  107404.34
# 26   75328.87       144135.98        134050.07     Florida  105733.54
# 27   72107.60       127864.55        353183.81    New York  105008.31
# 28   66051.52       182645.56        118148.20     Florida  103282.38
# 29   65605.48       153032.06        107138.38    New York  101004.64
# 30   61994.48       115641.28         91131.24     Florida   99937.59
# 31   61136.38       152701.92         88218.23    New York   97483.56
# 32   63408.86       129219.61         46085.25  California   97427.84
# 33   55493.95       103057.49        214634.81     Florida   96778.92
# 34   46426.07       157693.92        210797.67  California   96712.80
# 35   46014.02        85047.44        205517.64    New York   96479.51
# 36   28663.76       127056.21        201126.82     Florida   90708.19
# 37   44069.95        51283.14        197029.42  California   89949.14
# 38   20229.59        65947.93        185265.10    New York   81229.06
# 39   38558.51        82982.09        174999.30  California   81005.76
# 40   28754.33       118546.05        172795.67  California   78239.91
# 41   27892.92        84710.77        164470.71     Florida   77798.83
# 42   23640.93        96189.63        148001.11  California   71498.49
# 43   15505.73       127382.30         35534.17    New York   69758.98
# 44   22177.74       154806.14         28334.72  California   65200.33
# 45    1000.23       124153.04          1903.93    New York   64926.08
# 46    1315.46       115816.21        297114.46     Florida   49490.75
# 47       0.00       135426.92             0.00  California   42559.73
# 48     542.05        51743.15             0.00    New York   35673.41
# 49       0.00       116983.80         45173.06  California   14681.40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
df.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
x=df.drop(['State','Profit'],axis=1)
x
# Out:
#     R&D Spend  Administration  Marketing Spend
# 0   165349.20       136897.80        471784.10
# 1   162597.70       151377.59        443898.53
# 2   153441.51       101145.55        407934.54
# 3   144372.41       118671.85        383199.62
# 4   142107.34        91391.77        366168.42
# 5   131876.90        99814.71        362861.36
# 6   134615.46       147198.87        127716.82
# 7   130298.13       145530.06        323876.68
# 8   120542.52       148718.95        311613.29
# 9   123334.88       108679.17        304981.62
# 10  101913.08       110594.11        229160.95
# 11  100671.96        91790.61        249744.55
# 12   93863.75       127320.38        249839.44
# 13   91992.39       135495.07        252664.93
# 14  119943.24       156547.42        256512.92
# 15  114523.61       122616.84        261776.23
# 16   78013.11       121597.55        264346.06
# 17   94657.16       145077.58        282574.31
# 18   91749.16       114175.79        294919.57
# 19   86419.70       153514.11             0.00
# 20   76253.86       113867.30        298664.47
# 21   78389.47       153773.43        299737.29
# 22   73994.56       122782.75        303319.26
# 23   67532.53       105751.03        304768.73
# 24   77044.01        99281.34        140574.81
# 25   64664.71       139553.16        137962.62
# 26   75328.87       144135.98        134050.07
# 27   72107.60       127864.55        353183.81
# 28   66051.52       182645.56        118148.20
# 29   65605.48       153032.06        107138.38
# 30   61994.48       115641.28         91131.24
# 31   61136.38       152701.92         88218.23
# 32   63408.86       129219.61         46085.25
# 33   55493.95       103057.49        214634.81
# 34   46426.07       157693.92        210797.67
# 35   46014.02        85047.44        205517.64
# 36   28663.76       127056.21        201126.82
# 37   44069.95        51283.14        197029.42
# 38   20229.59        65947.93        185265.10
# 39   38558.51        82982.09        174999.30
# 40   28754.33       118546.05        172795.67
# 41   27892.92        84710.77        164470.71
# 42   23640.93        96189.63        148001.11
# 43   15505.73       127382.30         35534.17
# 44   22177.74       154806.14         28334.72
# 45    1000.23       124153.04          1903.93
# 46    1315.46       115816.21        297114.46
# 47       0.00       135426.92             0.00
# 48     542.05        51743.15             0.00
# 49       0.00       116983.80         45173.06

# %%
y=df['Profit']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=40)

# %%
x_train
# Out:
#     R&D Spend  Administration  Marketing Spend
# 16   78013.11       121597.55        264346.06
# 35   46014.02        85047.44        205517.64
# 25   64664.71       139553.16        137962.62
# 21   78389.47       153773.43        299737.29
# 44   22177.74       154806.14         28334.72
# 41   27892.92        84710.77        164470.71
# 23   67532.53       105751.03        304768.73
# 36   28663.76       127056.21        201126.82
# 5   131876.90        99814.71        362861.36
# 13   91992.39       135495.07        252664.93
# 39   38558.51        82982.09        174999.30
# 17   94657.16       145077.58        282574.31
# 43   15505.73       127382.30         35534.17
# 24   77044.01        99281.34        140574.81
# 3   144372.41       118671.85        383199.62
# 22   73994.56       122782.75        303319.26
# 40   28754.33       118546.05        172795.67
# 26   75328.87       144135.98        134050.07
# 34   46426.07       157693.92        210797.67
# 20   76253.86       113867.30        298664.47
# 28   66051.52       182645.56        118148.20
# 14  119943.24       156547.42        256512.92
# 15  114523.61       122616.84        261776.23
# 30   61994.48       115641.28         91131.24
# 8   120542.52       148718.95        311613.29
# 46    1315.46       115816.21        297114.46
# 32   63408.86       129219.61         46085.25
# 9   123334.88       108679.17        304981.62
# 48     542.05        51743.15             0.00
# 42   23640.93        96189.63        148001.11
# 10  101913.08       110594.11        229160.95
# 31   61136.38       152701.92         88218.23
# 19   86419.70       153514.11             0.00
# 47       0.00       135426.92             0.00
# 12   93863.75       127320.38        249839.44
# 1   162597.70       151377.59        443898.53
# 37   44069.95        51283.14        197029.42
# 7   130298.13       145530.06        323876.68
# 27   72107.60       127864.55        353183.81
# 6   134615.46       147198.87        127716.82

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)
x_train=scaler.transform(x_train)
x_test=scaler.transform(x_test)

# %%
x_train
# Out:
# array([[ 0.13880434, -0.09372666,  0.5244613 ],
#        [-0.63334104, -1.40182563,  0.00312764],
#        [-0.18329561,  0.54889015, -0.59554059],
#        [ 0.147886  ,  1.05782216,  0.83809609],
#        [-1.20851594,  1.09478201, -1.56705596],
#        [-1.07060733, -1.41387478, -0.36062761],
#        [-0.11409446, -0.66086083,  0.88268439],
#        [-1.05200679,  0.10163439, -0.03578353],
#        [ 1.43854994, -0.87331694,  1.39749753],
#        [ 0.47612757,  0.40365438,  0.42094388],
#        [-0.8132442 , -1.47574285, -0.26732392],
#        [ 0.54042908,  0.74660469,  0.68599887],
#        [-1.36951307,  0.11330488, -1.5032549 ],
#        [ 0.11541974, -0.89240583, -0.57239153],
#        [ 1.74006947, -0.1984351 ,  1.57773387],
#        [ 0.04183581, -0.0513093 ,  0.86983928],
#        [-1.04982131, -0.20293738, -0.28685235],
#        [ 0.07403302,  0.71290559, -0.63021336],
#        [-0.62339818,  1.19813333,  0.04991892],
#        [ 0.09635324, -0.37038607,  0.82858883],
#        [-0.14983157,  2.09113242, -0.7711347 ],
#        [ 1.15058799,  1.15710102,  0.45504452],
#        [ 1.01981108, -0.05724709,  0.50168763],
#        [-0.24772887, -0.30689676, -1.01055726],
#        [ 1.16504876,  0.87692639,  0.94334044],
#        [-1.71192754, -0.30063615,  0.81485274],
#        [-0.21359956,  0.17906073, -1.40975191],
#        [ 1.23242904, -0.55606506,  0.88457101],
#        [-1.7305901 , -2.59375933, -1.81815642],
#        [-1.17320883, -1.00305563, -0.50658014],
#        [ 0.7155161 , -0.4875309 ,  0.21265312],
#        [-0.26843502,  1.01947368, -1.03637216],
#        [ 0.34165729,  1.0485413 , -1.81815642],
#        [-1.74366989,  0.40121535, -1.81815642],
#        [ 0.52128392,  0.11108882,  0.39590457],
#        [ 2.17984989,  0.97207697,  2.1156437 ],
#        [-0.68025189, -2.61022272, -0.07209442],
#        [ 1.40045386,  0.76279859,  1.05201781],
#        [-0.00369697,  0.13056422,  1.3117357 ],
#        [ 1.50463203,  0.82252395, -0.68633821]])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

# %%
models={
    'LR':LinearRegression(),
    'KNN':KNeighborsRegressor(n_neighbors=5),
    'SVR':SVR(),
    'DT':DecisionTreeRegressor(),
    'RF':RandomForestRegressor(n_estimators=5),
    'XGBR':XGBRegressor()
}

# %%
for name,model in models.items():
    print(f"using= {name}")
    model.fit(x_train,y_train)
    print(f"training accuracy : {model.score(x_train,y_train)}")
    print(f"testing accuracy : {model.score(x_test,y_test)}")
    print('_'*30)
# Out:
# using= LR
# training accuracy : 0.9576831818707999
# testing accuracy : 0.9359184298694548
# ______________________________
# using= KNN
# training accuracy : 0.8485052063773473
# testing accuracy : 0.8456384224323321
# ______________________________
# using= SVR
# training accuracy : -0.005274352831417639
# testing accuracy : -0.031656763326308734
# ______________________________
# using= DT
# training accuracy : 1.0
# testing accuracy : 0.9441873677349074
# ______________________________
# using= RF
# training accuracy : 0.9793875523343655
# testing accuracy : 0.939221663524645
# ______________________________
# using= XGBR
# training accuracy : 0.9999999999992499
# testing accuracy : 0.9372222293201717
# ______________________________

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x=df['Marketing Spend'],y=df['Profit'])

# %%
sns.jointplot(x=df['R&D Spend'],y=df['Profit'])

# %%
model=RandomForestRegressor()
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
model.score(x_test,y_test)
# Out:
# 0.9292711601066572

# %%
x.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend'], dtype='object')

# %%
data=[22,5.2,9.6]

# %%
data=scaler.transform([data])
data
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-1.74313902, -4.44541886, -1.81807135]])

# %%
pred=model.predict(data)

# %%
pred
# Out:
# array([43644.3902])

# %%
import joblib

# %%
joblib.dump(model,'model_50.h5')
joblib.dump(scaler,'scaler_50.h5')
joblib.dump(x.columns,'feature_50.h5')
# Out:
# ['feature_50.h5']

# %%
model=joblib.load('model_50.h5')

# %%
model?
