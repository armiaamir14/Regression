# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('Houses prices.csv')
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
df['date']
# Out:
# 0       2014-05-02 00:00:00
# 1       2014-05-02 00:00:00
# 2       2014-05-02 00:00:00
# 3       2014-05-02 00:00:00
# 4       2014-05-02 00:00:00
#                ...
# 4595    2014-07-09 00:00:00
# 4596    2014-07-09 00:00:00
# 4597    2014-07-09 00:00:00
# 4598    2014-07-10 00:00:00
# 4599    2014-07-10 00:00:00
# Name: date, Length: 4600, dtype: object

# %%
df['date']=pd.to_datetime(df['date'],format='%Y-%m-%d %H:%M:%S',errors='coerce')
df
# Out:
#            date         price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0    2014-05-02  3.130000e+05       3.0       1.50         1340      7912
# 1    2014-05-02  2.384000e+06       5.0       2.50         3650      9050
# 2    2014-05-02  3.420000e+05       3.0       2.00         1930     11947
# 3    2014-05-02  4.200000e+05       3.0       2.25         2000      8030
# 4    2014-05-02  5.500000e+05       4.0       2.50         1940     10500
# ...         ...           ...       ...        ...          ...       ...
# 4595 2014-07-09  3.081667e+05       3.0       1.75         1510      6360
# 4596 2014-07-09  5.343333e+05       3.0       2.50         1460      7573
# 4597 2014-07-09  4.169042e+05       3.0       2.50         3010      7014
# 4598 2014-07-10  2.034000e+05       4.0       2.00         2090      6630
# 4599 2014-07-10  2.206000e+05       3.0       2.50         1490      8102
#
#       floors  waterfront  view  condition  sqft_above  sqft_basement  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   datetime64[ns]
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
df['Year']=df['date'].dt.year
df['Month']=df['date'].dt.month
df['Day']=df['date'].dt.day_name()

# %%
df
# Out:
#            date         price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0    2014-05-02  3.130000e+05       3.0       1.50         1340      7912
# 1    2014-05-02  2.384000e+06       5.0       2.50         3650      9050
# 2    2014-05-02  3.420000e+05       3.0       2.00         1930     11947
# 3    2014-05-02  4.200000e+05       3.0       2.25         2000      8030
# 4    2014-05-02  5.500000e+05       4.0       2.50         1940     10500
# ...         ...           ...       ...        ...          ...       ...
# 4595 2014-07-09  3.081667e+05       3.0       1.75         1510      6360
# 4596 2014-07-09  5.343333e+05       3.0       2.50         1460      7573
# 4597 2014-07-09  4.169042e+05       3.0       2.50         3010      7014
# 4598 2014-07-10  2.034000e+05       4.0       2.00         2090      6630
# 4599 2014-07-10  2.206000e+05       3.0       2.50         1490      8102
#
#       floors  waterfront  view  condition  ...  sqft_basement  yr_built  \
# ...

# %%
df.drop(['waterfront'],axis=1,inplace=True)

# %%
df
# Out:
#            date         price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0    2014-05-02  3.130000e+05       3.0       1.50         1340      7912
# 1    2014-05-02  2.384000e+06       5.0       2.50         3650      9050
# 2    2014-05-02  3.420000e+05       3.0       2.00         1930     11947
# 3    2014-05-02  4.200000e+05       3.0       2.25         2000      8030
# 4    2014-05-02  5.500000e+05       4.0       2.50         1940     10500
# ...         ...           ...       ...        ...          ...       ...
# 4595 2014-07-09  3.081667e+05       3.0       1.75         1510      6360
# 4596 2014-07-09  5.343333e+05       3.0       2.50         1460      7573
# 4597 2014-07-09  4.169042e+05       3.0       2.50         3010      7014
# 4598 2014-07-10  2.034000e+05       4.0       2.00         2090      6630
# 4599 2014-07-10  2.206000e+05       3.0       2.50         1490      8102
#
#       floors  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
df.drop(['Day'],axis=1,inplace=True)

# %%
df.drop(['statezip','street'],axis=1,inplace=True)

# %%
df
# Out:
#            date         price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0    2014-05-02  3.130000e+05       3.0       1.50         1340      7912
# 1    2014-05-02  2.384000e+06       5.0       2.50         3650      9050
# 2    2014-05-02  3.420000e+05       3.0       2.00         1930     11947
# 3    2014-05-02  4.200000e+05       3.0       2.25         2000      8030
# 4    2014-05-02  5.500000e+05       4.0       2.50         1940     10500
# ...         ...           ...       ...        ...          ...       ...
# 4595 2014-07-09  3.081667e+05       3.0       1.75         1510      6360
# 4596 2014-07-09  5.343333e+05       3.0       2.50         1460      7573
# 4597 2014-07-09  4.169042e+05       3.0       2.50         3010      7014
# 4598 2014-07-10  2.034000e+05       4.0       2.00         2090      6630
# 4599 2014-07-10  2.206000e+05       3.0       2.50         1490      8102
#
#       floors  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.drop(['view','date','sqft_living','sqft_lot','sqft_basement'],axis=1,inplace=True)

# %%
df.drop(['country','city'],axis=1,inplace=True)

# %%
df
# Out:
#              price  bedrooms  bathrooms  floors  condition  sqft_above  \
# 0     3.130000e+05       3.0       1.50     1.5          3        1340
# 1     2.384000e+06       5.0       2.50     2.0          5        3370
# 2     3.420000e+05       3.0       2.00     1.0          4        1930
# 3     4.200000e+05       3.0       2.25     1.0          4        1000
# 4     5.500000e+05       4.0       2.50     1.0          4        1140
# ...            ...       ...        ...     ...        ...         ...
# 4595  3.081667e+05       3.0       1.75     1.0          4        1510
# 4596  5.343333e+05       3.0       2.50     2.0          3        1460
# 4597  4.169042e+05       3.0       2.50     2.0          3        3010
# 4598  2.034000e+05       4.0       2.00     1.0          3        1070
# 4599  2.206000e+05       3.0       2.50     2.0          4        1490
#
#       yr_built  yr_renovated  Year  Month
# 0         1955          2005  2014      5
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
x=df.drop(['price'],axis=1)
y=df['price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#       bedrooms  bathrooms  floors  condition  sqft_above  yr_built  \
# 1861       2.0       1.00     1.0          3         670      1919
# 1030       4.0       2.50     2.0          3        3550      2007
# 1021       3.0       2.50     2.0          3        2170      2004
# 1330       4.0       2.50     1.0          3        1470      1921
# 2775       6.0       1.00     1.5          3        1120      1931
# ...        ...        ...     ...        ...         ...       ...
# 1169       4.0       2.75     2.0          3        1720      1998
# 2759       5.0       3.00     2.0          3        2795      1996
# 280        3.0       2.00     1.0          4        1010      1917
# 1609       4.0       2.50     1.0          5        2210      1946
# 1034       3.0       2.25     2.0          3        1680      2008
#
#       yr_renovated  Year  Month
# 1861          2001  2014      6
# 1030             0  2014      5
# 1021          2003  2014      5
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)
x_train
# Out:
# array([[-1.54835352, -1.48165488, -0.95623993, ...,  1.22611144,
#          0.        ,  0.35691223],
#        [ 0.65715875,  0.42092958,  0.9007326 , ..., -0.82011743,
#          0.        , -1.0976138 ],
#        [-0.44559738,  0.42092958,  0.9007326 , ...,  1.22815665,
#          0.        , -1.0976138 ],
#        ...,
#        [-0.44559738, -0.21326524, -0.95623993, ..., -0.82011743,
#          0.        , -1.0976138 ],
#        [ 0.65715875,  0.42092958, -0.95623993, ..., -0.82011743,
#          0.        , -1.0976138 ],
#        [-0.44559738,  0.10383217,  0.9007326 , ..., -0.82011743,
#          0.        , -1.0976138 ]])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

# %%
models={
    'LR':LinearRegression(),
    'KNN':KNeighborsRegressor(n_neighbors=5),
    'SVR':SVR(),
    'DT':DecisionTreeRegressor(),
    'RF':RandomForestRegressor(n_estimators=5),
    'XGBR':XGBRegressor()
}

# %%
for name,model in models.items():
    print(f"using= {name}")
    model.fit(x_train,y_train)
    print(f"training accuracy : {model.score(x_train,y_train)}")
    print(f"testing accuracy : {model.score(x_test,y_test)}")
    print('_'*30)
# Out:
# using= LR
# training accuracy : 0.15684789187037318
# testing accuracy : 0.44535563463287076
# ______________________________
# using= KNN
# training accuracy : 0.33113672901872504
# testing accuracy : 0.009268397623731883
# ______________________________
# using= SVR
# training accuracy : -0.02433420289526489
# testing accuracy : -0.05049772792660323
# ______________________________
# using= DT
# training accuracy : 0.9999634243556456
# testing accuracy : -0.2160714840166349
# ______________________________
# using= RF
# training accuracy : 0.709928020951256
# testing accuracy : 0.1318713651249529
# ______________________________
# using= XGBR
# training accuracy : 0.9549508326945428
# testing accuracy : 0.10806463815425182
# ______________________________

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x.columns
# Out:
# Index(['bedrooms', 'bathrooms', 'floors', 'condition', 'sqft_above',
#        'yr_built', 'yr_renovated', 'Year', 'Month'],
#       dtype='object')

# %%
data=[2,2,3.5,2,1,1999,2012,2019,6]

# %%
data=scaler.transform([data])
data
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-1.54835352, -0.21326524,  3.6861914 , -2.15246117, -2.10382625,
#          0.94707468,  1.23736008,  5.        ,  0.35691223]])

# %%
pred=model.predict(data)
pred
# Out:
# array([3592.71550858])

# %%
import joblib

# %%
joblib.dump(model,'model_house.h5')
joblib.dump(scaler,'scaler_house.h5')
joblib.dump(x.columns,'feature_house.h5')
# Out:
# ['feature_house.h5']

# %%
model=joblib.load('model_50.h5')
model?
